# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np 
import matplotlib.pyplot as pltpip 
import seaborn as sns


df = pd.read_excel ("Detalle precios y productos fabricados 2022.xlsx")
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %% [markdown]
# **En este flitro se filtro por el nombre del vendedor DIEGO ARMANDO LEON DURAN**
# Aqui abajo se mostro los datos filtrados por nombre_vendedor

# %%
filtro1=df[(df["NOMBRE_VENDEDOR"] == "DIEGO ARMANDO LEON DURAN")]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 2     F37041 2022-01-05  DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05  DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05  DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05  DIEGO ARMANDO LEON DURAN
# ...      ...        ...                       ...
# 519   F38005 2022-04-27  DIEGO ARMANDO LEON DURAN
# 580   F38141 2022-05-12  DIEGO ARMANDO LEON DURAN
# 731   F38459 2022-06-24  DIEGO ARMANDO LEON DURAN
# 851   F38665 2022-07-26  DIEGO ARMANDO LEON DURAN
# 1296  F39592 2022-11-16  DIEGO ARMANDO LEON DURAN
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 2               ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                    OMAR RODRIGUEZ GOMEZ     1    TP0001
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 8                      FIDEICOMISO F/1596     1  TUE00207
# 9                      FIDEICOMISO F/1596     1  TUE00207
# ...

# %%
filtro1.to_csv("Filtro 1.csv")

# %% [markdown]
# **En este flitro se filtro por Nombre_vendedor y tome la variable de DIEGO ARMANDO LEON DURAN**
# Aqui abajo se mostro los datos filtrados por nombre_vendedor

# %%
filtro2 = df.iloc[3:11, :]
filtro2
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 3   F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6   F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7   F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8   F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9   F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10  F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                          NOMBRE_CLIENTE  CANT   CVE_ART  \
# 3                  OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                    PÚBLICO EN GENERAL     2   BP00242
# 5                    PÚBLICO EN GENERAL     2   BP00243
# 6   AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 7             ANA BARBARA CRUZ PALACIOS     3    TP0001
# 8                    FIDEICOMISO F/1596     1  TUE00207
# 9                    FIDEICOMISO F/1596     1  TUE00207
# 10                   FIDEICOMISO F/1596     1  TUE00207
#
# ...

# %%
filtro2.to_csv("Filtro 2.csv")

# %% [markdown]
# **En este flitro se filtro por filas**
# Aqui abajo se mostro los datos filtrados por la fila de la 3 a la 11 y se tomaron todas las columnas que tiene

# %%
#filtro por columnas
filtro3 = df.iloc[:, [1,4,5]]
filtro3
# Out:
#       FECHA_DOC  CANT       CVE_ART
# 0    2022-01-05     1      TUE00244
# 1    2022-01-05     1      TUA00028
# 2    2022-01-05     7        TP0007
# 3    2022-01-05     1        TP0001
# 4    2022-01-05     2       BP00242
# ...         ...   ...           ...
# 1421 2022-12-23     6  CS12F1040A00
# 1422 2022-12-23     6  CS12H1050A00
# 1423 2022-12-23     3      TUE00394
# 1424 2022-12-23     1      TUA00470
# 1425 2022-12-23    10       RB00007
#
# [1426 rows x 3 columns]

# %%
filtro3.to_csv("Filtro 3.csv")

# %% [markdown]
# **En este flitro se filtro por columnas**
# Aqui abajo se mostro los datos filtrados por las columnas 1,4 y 5,se tomaron todas las filas que se tiene

# %%
df1=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx',index_col=1)
df1
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...            ...                        ...                           ...
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 2022-12-23  F39838         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
# ...

# %%
df1.to_csv("Filtro 4.csv")

# %% [markdown]
# **En este flitro lo que hizo fue que ahora se inicio desde cve_doc**
# Aqui creo fue un error pero marcar fecha antes de cve_doc pero lo que realiza este filtro es que elimina la id que se le da por defecto a las columnas

# %%
#filtro de filas vs columnas
filtro5 = df1.loc[["2022-01-05","2022-12-23"], ["NOMBRE_VENDEDOR"]]
filtro5
# Out:
#                       NOMBRE_VENDEDOR
# FECHA_DOC
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05   DIEGO ARMANDO LEON DURAN
# 2022-01-05             ALFREDO CANELA
# 2022-01-05             ALFREDO CANELA
# 2022-01-05             ALFREDO CANELA
# 2022-12-23             ALFREDO CANELA
# 2022-12-23         AARON NUÑO CORDOVA
# ...

# %%
filtro5.to_csv("Filtro 5.csv")

# %% [markdown]
# **En este filtro se ocupan las filas de las fechas 2022-01-05, 2022-12-23 y las columna de NOMBRE_VENDEDOR**
# En este filtro se logra ver en esas dos fechas todas los nombres de los Nombres_vendedores

# %%
#Si no tiene nada dentro del parentesis genera los primeros 5 registros por cabecera
filtro6 = df1.head()
filtro6
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#             CANT   CVE_ART                                    DESCR  \
# FECHA_DOC
# 2022-01-05     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V
# 2022-01-05     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT
# 2022-01-05     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT
# 2022-01-05     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT
# 2022-01-05     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR
#
#             PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# ...

# %%
filtro6.to_csv("Filtro 6.csv")

# %% [markdown]
# **En este filtro se ocupan todas las columna pero solo los primeros datos de cada columna**
# En este filtro se muestran los datos que estan de cabecera de cada columna pero solo se muestran las primeras 5 filas

# %%
filtro7= df1.tail()
filtro7
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 2022-12-23  F39838         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#             CANT       CVE_ART                                     DESCR  \
# FECHA_DOC
# 2022-12-23     6  CS12F1040A00      CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 2022-12-23     6  CS12H1050A00       CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# 2022-12-23     3      TUE00394  TUB INOX 5/16"ØX300MM 5300W 220V "M" ESP
# 2022-12-23     1      TUA00470  TUB INOX 1/2"ØX500MM 10KW 220V 2 1/2"NPT
# 2022-12-23    10       RB00007   FAB  BOBINA DSD1 6 COLOCAR B/NUEVA 488V
#
# ...

# %%
filtro7.to_csv("Filtro 7.csv")

# %% [markdown]
# **En este filtro se ocupan todas las columna pero solo los ultimos datos de cada columna**
# En este filtro se muestran los datos que estan de cola de cada columna pero solo se muestran las ultimas 5 filas

# %%
filtro8 = df1[df1["MARGEN_TOTAL_CALCULADO"]>3000]
filtro8
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR  \
# FECHA_DOC
# 2022-01-05  F37044   DIEGO ARMANDO LEON DURAN
# 2022-01-05  F37061             ALFREDO CANELA
# 2022-01-05  F37061             ALFREDO CANELA
# 2022-01-07  F37077   DIEGO ARMANDO LEON DURAN
# 2022-01-07  F37078             ALFREDO CANELA
# ...            ...                        ...
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ
# 2022-12-23  F39838         AARON NUÑO CORDOVA
#
#                                  NOMBRE_CLIENTE  CANT       CVE_ART  \
# FECHA_DOC
# 2022-01-05  AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# 2022-01-05                             ELICAMEX     5      WRE-2133
# 2022-01-05                             ELICAMEX     7      WRE-2774
# 2022-01-07                JOSE LUIS CHAVEZ LUNA     2       PT00044
# ...

# %%
filtro8.to_csv("Filtro 8.csv")

# %% [markdown]
# **En este filtro se muestra toda la informacion de las columnas pero en MARGEN_TOTAL_CALCULADO van a salir cantidaddes arriba de 3000**
# En este filtro se mostraron todos los datos de las columnas pero solo se muestran si estan arriba de 3000

# %%
filtro9 = df[(df["MARGEN_TOTAL_CALCULADO"]< 3000) & (df["FECHA_DOC"] == "2022-12-23")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1414  JUAN GERARDO GUZMAN FLORES     3       TP00018
# 1416                      TORJJS     3  PJ31Q1G1A400
# 1417             TRILOGIQ-MEXICO     2       BL00002
# 1420             TRILOGIQ-MEXICO     2       PT00079
#
#                                          DESCR  PRECIO_UNITARIO  \
# 1414      TIRA INOX 38MMX6" 150W 127V T/TIPO H           510.00
# 1416  TER J 3/16"ØX1/2" EXT3MT MALLA INOX  Z/E           439.15
# 1417  BL INOX 60mmØx50mm 400W 120/240V EXT30CM           925.82
# 1420    PT-100 7.5MMØX95MM EXT.48CM 3H C/MACHO          1177.07
#
#       COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# ...

# %%
filtro9.to_csv("Filtro 9.csv")

# %% [markdown]
# **En este filtro se muestra toda la informacion de las columnas pero en MARGEN_TOTAL_CALCULADO o van a salir cantidaddes arriba de 3000**
# En este filtro se mostraron todos los datos de las columnas pero solo se muestran si estan abajo de 3000 o si son de la fecha del 2022-12-23

# %%
#filtro 10
filtro10 = df[(df["MARGEN_TOTAL_CALCULADO"]< 3000) | (df["FECHA_DOC"] == "2022-12-23")]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
filtro10.to_csv("Filtro 10.csv")

# %% [markdown]
# **En este filtro se muestra toda la informacion de las columnas pero en MARGEN_TOTAL_CALCULADO  y van a salir cantidades arriba de 3000**
# En este filtro se mostraron todos los datos de las columnas pero solo se muestran si estan abajo de 3000 y si son de la fecha del 2022-12-23

# %%
filtro11=df[~(df['FECHA_DOC'] == "2022-12-23")]
filtro11
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1407  F39815 2022-12-22             ALFREDO CANELA
# 1408  F39815 2022-12-22             ALFREDO CANELA
# 1409  F39816 2022-12-22             ALFREDO CANELA
# 1410  F39817 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1411  F39820 2022-12-22         AARON NUÑO CORDOVA
#
#                                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0                                    PÚBLICO EN GENERAL     1      TUE00244
# 1                          JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2                             ANA BARBARA CRUZ PALACIOS     7        TP0007
# ...

# %%
filtro11.to_csv("Filtro 11.csv")

# %% [markdown]
# **En este filtro se muestra todos los registros que no sean de los valores de FECHA_DOC 2022-12-23**
# Lo que hace este filtro es mostrar todos los valores de todas las filas y columnas a excepcion de donde la FECHA_DOC sea 2022-12-23
