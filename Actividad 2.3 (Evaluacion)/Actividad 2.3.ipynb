# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np 
import matplotlib.pyplot as pltpip 
import seaborn as sns

df = pd.read_csv ("listings.csv")
df
# Out:
#                         id                                       listing_url  \
# 0                    27934                https://www.airbnb.com/rooms/27934
# 1                    27979                https://www.airbnb.com/rooms/27979
# 2                    28745                https://www.airbnb.com/rooms/28745
# 3                    35780                https://www.airbnb.com/rooms/35780
# 4                    48736                https://www.airbnb.com/rooms/48736
# ...                    ...                                               ...
# 25074  1252462451305524959  https://www.airbnb.com/rooms/1252462451305524959
# 25075  1252465334122867402  https://www.airbnb.com/rooms/1252465334122867402
# 25076  1252478699202812971  https://www.airbnb.com/rooms/1252478699202812971
# 25077  1252484092218301658  https://www.airbnb.com/rooms/1252484092218301658
# 25078  1252486847996346909  https://www.airbnb.com/rooms/1252486847996346909
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25079 entries, 0 to 25078
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            25079 non-null  int64
#  1   listing_url                                   25079 non-null  object
#  2   scrape_id                                     25079 non-null  int64
#  3   last_scraped                                  25079 non-null  object
#  4   source                                        25079 non-null  object
#  5   name                                          25079 non-null  object
#  6   description                                   24125 non-null  object
#  7   neighborhood_overview                         10160 non-null  object
#  8   picture_url                                   25079 non-null  object
# ...

# %%
filtro1= df[["host_name"]].head()
filtro1
# Out:
#     host_name
# 0      Nuttee
# 1         Emy
# 2  Familyroom
# 3     Sirilak
# 4    Athitaya

# %%
filtro1.to_csv("Filtro 1.csv")

# %%
filtro2 = df[df["host_since"]<'2019-01-01']
filtro2
# Out:
#                         id                                       listing_url  \
# 0                    27934                https://www.airbnb.com/rooms/27934
# 1                    27979                https://www.airbnb.com/rooms/27979
# 2                    28745                https://www.airbnb.com/rooms/28745
# 3                    35780                https://www.airbnb.com/rooms/35780
# 4                    48736                https://www.airbnb.com/rooms/48736
# ...                    ...                                               ...
# 25062  1251921602019825583  https://www.airbnb.com/rooms/1251921602019825583
# 25064  1251946560828337822  https://www.airbnb.com/rooms/1251946560828337822
# 25065  1251969958594815477  https://www.airbnb.com/rooms/1251969958594815477
# 25070  1252105816106486520  https://www.airbnb.com/rooms/1252105816106486520
# 25071  1252184411531566246  https://www.airbnb.com/rooms/1252184411531566246
#
# ...

# %%
filtro2.to_csv("Filtro 2.csv")

# %%
filtro3 = df[["host_response_time"] == 'within a day' ]
filtro3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 filtro3 = df[["host_response_time"] == 'within a day' ]
# ...
